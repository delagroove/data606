# %% [markdown]
# # Homework 1
# ## Alvaro Bueno
#
# For me the best method to work and generate a graph is a dictionary, so i went and create it directly. I also tried to label the existing kite graph generated nodes but you have more control by creating the nodes manually.

# %%
import networkx as nx
graph = {"Beverly":["Andre", "Diane", "Garth", "Ed"], "Ed":["Garth", "Beverly", "Diane"], "Garth": ["Diane","Fernando", "Beverly", "Ed", "Heather"], "Andre":["Beverly", "Fernando", "Carol", "Diane"], "Diane":["Ed", "Garth", "Fernando", "Andre", "Beverly", "Carol"], "Carol":["Andre", "Fernando", "Diane"], "Fernando": ["Carol", "Andre", "Diane", "Garth","Heather"], "Heather":["Ike","Fernando", "Garth"], "Ike": ["Heather", "Jane"], "Jane": ["Ike"]}
# g = nx.generators.small.krackhardt_kite_graph()
G = nx.Graph(graph)
nx.draw_networkx(G)
